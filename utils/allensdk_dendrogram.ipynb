# %%
import allensdk.core.swc as swc
import allensdk.morphology as morph
import allensdk.morphology.validate_swc as valswc

# %%
swcFile = 'cleanedDNa02.swc'

valswc.validate_swc(swcFile)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\allensdk\core\swc.py:94, in read_swc(file_name, columns, numeric_columns)
#      92 toks = line.split(' ')
#      93 vals = Compartment({
# ---> 94     NODE_ID: int(toks[0]),
#      95     NODE_TYPE: int(toks[1]),
#      96     NODE_X: float(toks[2]),
#      97     NODE_Y: float(toks[3]),
#      98     NODE_Z: float(toks[4]),
#      99     NODE_R: float(toks[5]),
#     100     NODE_PN: int(toks[6].rstrip())
#     101 })
#     102 # store this compartment
#
# ValueError: invalid literal for int() with base 10: '\n'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 swcFile = 'cleanedDNa02.swc'
# ----> 3 valswc.validate_swc(swcFile)
#
# ...

# %%
swcFile = 'cleanedDNa02_NoHeader.swc'

valswc.validate_swc(swcFile)
# Out:
# Branch has multiple axon roots
# {'id': 37, 'type': 2, 'x': 18018.0, 'y': 26828.0, 'z': 24242.0, 'radius': 10.0, 'parent': 36, 'tree_id': 0, 'children': [38, 60]}
# {'id': 30, 'type': 2, 'x': 18138.0, 'y': 26654.0, 'z': 24150.0, 'radius': 19.4558, 'parent': 29, 'tree_id': 0, 'children': [31, 91]}
# Branch has multiple axon roots
# {'id': 183, 'type': 2, 'x': 20976.5, 'y': 25258.0, 'z': 24844.3, 'radius': 32.5423, 'parent': 182, 'tree_id': 0, 'children': [184, 203]}
# {'id': 169, 'type': 2, 'x': 20658.0, 'y': 25298.0, 'z': 25482.0, 'radius': 14.1421, 'parent': 168, 'tree_id': 0, 'children': [170, 220]}
# Branch has multiple axon roots
# {'id': 224, 'type': 2, 'x': 20671.3, 'y': 25364.7, 'z': 25578.7, 'radius': 10.0, 'parent': 223, 'tree_id': 0, 'children': [225, 241]}
# {'id': 169, 'type': 2, 'x': 20658.0, 'y': 25298.0, 'z': 25482.0, 'radius': 14.1421, 'parent': 168, 'tree_id': 0, 'children': [170, 220]}
# Branch has multiple axon roots
# ...
